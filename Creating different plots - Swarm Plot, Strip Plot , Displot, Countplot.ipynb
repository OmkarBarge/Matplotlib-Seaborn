# %%
# Installing seaborn
# pip install seaborn - In CMD line
# !pip install seaborn - In Jupyter cell
# OR
# %pip install seaborn - In Jupyter cell

# %%
# Importing Matplotlib
import matplotlib.pyplot as plt
# plt is athe alias name for pyplot
import numpy as np
# np is the alias for numpy
import pandas as pd
# pd is the alias for pandas
import seaborn as sns
# seaborn is aliased as sns

import warnings
warnings.filterwarnings("ignore")

# %%
# Loading Dataset
df = pd.read_csv('tips.csv')
# Print the Type of df
print(type(df))
# Show top 5 rows
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df['day'].unique() # finding unique values in day column
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %% [markdown]
# ## Strip Plot

# %%
# Plotting a Strip plot
sns.stripplot(data=df,x='smoker',y='tip')
# Setting title for the plot
plt.title('Smoker type vs Tips - Strip plot')
plt.show() # Showing the plot

# %%
plt.figure(figsize=(8,4)) # setting plot figure size
# Plotting a Strip plot
sns.stripplot(data=df,x='time',y='total_bill',hue='sex')
# Setting title for the plot
plt.title('Time wise Total bill based on sex - Strip plot')
plt.show()# Showing the plot

# %% [markdown]
# ## Swarm Plot

# %%
sns.swarmplot(data=df,x='sex',y='total_bill') # Plotting a Swarm plot
plt.title('Sex wise Total bill- Swarm plot') # Setting title for the plot
plt.grid() # Showing grid for the plot 
plt.show() # Showing the plot

# %%
plt.figure(figsize=(8,4)) # setting plot figure size
sns.swarmplot(data=df,x='smoker',y='tip',hue='time') # Plotting a Swarm plot
plt.title('Smoker type wise Tips based on Time - Swarm plot') # Setting title for the plot
plt.grid() # Showing grid for the plot 
plt.show() # Showing the plot

# %% [markdown]
# ## Displot

# %%
sns.displot(data=df,x='tip') # Plotting a Displot
plt.title('Displot of Tips') # Setting title for the plot
plt.show() #Showing the plot

# %%
sns.displot(data=df,x='size',kind='kde')# Plotting a Displot of type 'kde'
plt.title('Displot for size (KDE)') # Setting title for the plot
plt.show() #Showing the plot

# %% [markdown]
# ## Countplot

# %%
sns.countplot(data=df ,x = 'smoker') # Plotting a Countplot
plt.title('Countplot for Smoker type') # Setting title for the plot
plt.show()  # Showing the plot

# %%
plt.figure(figsize=(8,4)) # setting plot figure size
sns.countplot(data=df ,x ='smoker',hue='time') # Plotting a Countplot
plt.title('Smoker type based on Time - Countplot') # Setting title for the plot
plt.grid() # Showing grid for the plot 
plt.show() # Showing the plot
